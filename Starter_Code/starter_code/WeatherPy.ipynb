# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 594

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
print(f"{url}appid={weather_api_key}&units=metric&q=")
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=d09fb8f7906ea255879c752974dc65af&units=metric&q=

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  '&q=' + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url + 'appid=' + weather_api_key + city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nambucca heads
# Processing Record 2 of Set 1 | nijar
# Processing Record 3 of Set 1 | jamestown
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | avallon
# Processing Record 6 of Set 1 | nome
# Processing Record 7 of Set 1 | ahipara
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | nefteyugansk
# Processing Record 12 of Set 1 | saint george
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | sao gabriel da cachoeira
# Processing Record 15 of Set 1 | ziniare
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | bethel
# Processing Record 18 of Set 1 | moissac
# Processing Record 19 of Set 1 | ostrovnoy
# Processing Record 20 of Set 1 | dingle
# Processing Record 21 of Set 1 | broome
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 25 of Set 1 | carauari
# Processing Record 26 of Set 1 | todos santos
# Processing Record 27 of Set 1 | tabukiniberu
# City not found. Skipping...
# Processing Record 28 of Set 1 | ibra
# Processing Record 29 of Set 1 | peace river
# Processing Record 30 of Set 1 | cidreira
# Processing Record 31 of Set 1 | beyneu
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | coquimbo
# Processing Record 34 of Set 1 | geraldton
# Processing Record 35 of Set 1 | puerto quijarro
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 1 | makakilo city
# Processing Record 39 of Set 1 | teya
# Processing Record 40 of Set 1 | sosnovo-ozerskoye
# Processing Record 41 of Set 1 | madera
# Processing Record 42 of Set 1 | taksimo
# Processing Record 43 of Set 1 | mitsamiouli
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | sorong
# Processing Record 46 of Set 1 | port lincoln
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | luderitz
# Processing Record 49 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 50 of Set 1 | chuy
# Processing Record 0 of Set 2 | lompoc
# Processing Record 1 of Set 2 | mazyr
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | mezen
# Processing Record 4 of Set 2 | grindavik
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | norman wells
# Processing Record 7 of Set 2 | rikitea
# Processing Record 8 of Set 2 | newport
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | parabel
# Processing Record 11 of Set 2 | albany
# Processing Record 12 of Set 2 | paoua
# Processing Record 13 of Set 2 | cacu
# Processing Record 14 of Set 2 | nanchong
# Processing Record 15 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 2 | nabire
# Processing Record 17 of Set 2 | butaritari
# Processing Record 18 of Set 2 | mount gambier
# Processing Record 19 of Set 2 | ilulissat
# Processing Record 20 of Set 2 | sechura
# Processing Record 21 of Set 2 | hervey bay
# Processing Record 22 of Set 2 | zhangye
# Processing Record 23 of Set 2 | busselton
# Processing Record 24 of Set 2 | oxbow
# Processing Record 25 of Set 2 | bredasdorp
# Processing Record 26 of Set 2 | marystown
# Processing Record 27 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | yar-sale
# Processing Record 30 of Set 2 | yabelo
# Processing Record 31 of Set 2 | shangzhi
# Processing Record 32 of Set 2 | banda aceh
# Processing Record 33 of Set 2 | castro
# Processing Record 34 of Set 2 | hamilton
# Processing Record 35 of Set 2 | lixourion
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | talcahuano
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | khormuj
# City not found. Skipping...
# Processing Record 41 of Set 2 | natal
# Processing Record 42 of Set 2 | malanje
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | skelleftea
# Processing Record 45 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 2 | avarua
# Processing Record 47 of Set 2 | hofn
# Processing Record 48 of Set 2 | san matias
# Processing Record 49 of Set 2 | kangaatsiaq
# Processing Record 0 of Set 3 | cherskiy
# Processing Record 1 of Set 3 | esperance
# Processing Record 2 of Set 3 | meiganga
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | ballina
# Processing Record 5 of Set 3 | taltal
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | lodja
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | la ronge
# Processing Record 10 of Set 3 | naze
# Processing Record 11 of Set 3 | nanortalik
# Processing Record 12 of Set 3 | mount vernon
# Processing Record 13 of Set 3 | ciudad bolivar
# Processing Record 14 of Set 3 | severo-kurilsk
# Processing Record 15 of Set 3 | kaeo
# Processing Record 16 of Set 3 | souillac
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | sabang
# Processing Record 20 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 21 of Set 3 | tutoia
# Processing Record 22 of Set 3 | japura
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | oriximina
# Processing Record 25 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 3 | tuktoyaktuk
# Processing Record 27 of Set 3 | port augusta
# Processing Record 28 of Set 3 | inyonga
# Processing Record 29 of Set 3 | hihya
# Processing Record 30 of Set 3 | tuatapere
# Processing Record 31 of Set 3 | vanavara
# Processing Record 32 of Set 3 | iqaluit
# Processing Record 33 of Set 3 | isla vista
# Processing Record 34 of Set 3 | srednebelaya
# Processing Record 35 of Set 3 | bluff
# Processing Record 36 of Set 3 | nioro
# Processing Record 37 of Set 3 | sioux lookout
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 40 of Set 3 | khatanga
# Processing Record 41 of Set 3 | atbasar
# Processing Record 42 of Set 3 | san quintin
# Processing Record 43 of Set 3 | chokurdakh
# Processing Record 44 of Set 3 | lac du bonnet
# Processing Record 45 of Set 3 | kaitangata
# Processing Record 46 of Set 3 | minab
# Processing Record 47 of Set 3 | beisfjord
# Processing Record 48 of Set 3 | kuytun
# Processing Record 49 of Set 3 | krasnovka
# Processing Record 0 of Set 4 | herran
# Processing Record 1 of Set 4 | padang
# Processing Record 2 of Set 4 | andros
# Processing Record 3 of Set 4 | saint-philippe
# Processing Record 4 of Set 4 | kavaratti
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | sulangan
# Processing Record 7 of Set 4 | bengkulu
# Processing Record 8 of Set 4 | husavik
# Processing Record 9 of Set 4 | alofi
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 4 | chateauroux
# Processing Record 12 of Set 4 | kailua
# Processing Record 13 of Set 4 | adrar
# Processing Record 14 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 4 | grand-lahou
# Processing Record 16 of Set 4 | sola
# Processing Record 17 of Set 4 | snezhnogorsk
# Processing Record 18 of Set 4 | henties bay
# Processing Record 19 of Set 4 | mehamn
# Processing Record 20 of Set 4 | luang prabang
# Processing Record 21 of Set 4 | talnakh
# Processing Record 22 of Set 4 | mandalgovi
# Processing Record 23 of Set 4 | houma
# Processing Record 24 of Set 4 | port hedland
# Processing Record 25 of Set 4 | namibe
# Processing Record 26 of Set 4 | pisco
# Processing Record 27 of Set 4 | upernavik
# Processing Record 28 of Set 4 | montgomery
# Processing Record 29 of Set 4 | okato
# Processing Record 30 of Set 4 | hirara
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | hasaki
# Processing Record 33 of Set 4 | constitucion
# Processing Record 34 of Set 4 | port blair
# Processing Record 35 of Set 4 | del rio
# Processing Record 36 of Set 4 | santa flavia
# Processing Record 37 of Set 4 | san cristobal
# Processing Record 38 of Set 4 | parrita
# Processing Record 39 of Set 4 | high level
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | tura
# Processing Record 42 of Set 4 | quatre cocos
# Processing Record 43 of Set 4 | bud
# Processing Record 44 of Set 4 | buraydah
# Processing Record 45 of Set 4 | sitka
# Processing Record 46 of Set 4 | mersing
# Processing Record 47 of Set 4 | tucuma
# Processing Record 48 of Set 4 | abalak
# Processing Record 49 of Set 4 | kavieng
# Processing Record 0 of Set 5 | pontes e lacerda
# Processing Record 1 of Set 5 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 5 | homer
# Processing Record 3 of Set 5 | la tijera
# Processing Record 4 of Set 5 | nikolskoye
# Processing Record 5 of Set 5 | bambous virieux
# Processing Record 6 of Set 5 | vao
# Processing Record 7 of Set 5 | arraial do cabo
# Processing Record 8 of Set 5 | lugovoy
# Processing Record 9 of Set 5 | mezhdurechenskiy
# Processing Record 10 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 5 | dikson
# Processing Record 12 of Set 5 | narsaq
# Processing Record 13 of Set 5 | beringovskiy
# Processing Record 14 of Set 5 | wajima
# Processing Record 15 of Set 5 | kurumkan
# Processing Record 16 of Set 5 | kapaa
# Processing Record 17 of Set 5 | balimo
# City not found. Skipping...
# Processing Record 18 of Set 5 | faya
# Processing Record 19 of Set 5 | gat
# Processing Record 20 of Set 5 | svetlogorsk
# Processing Record 21 of Set 5 | katsuura
# Processing Record 22 of Set 5 | asosa
# Processing Record 23 of Set 5 | novi ligure
# Processing Record 24 of Set 5 | jand
# Processing Record 25 of Set 5 | aksha
# Processing Record 26 of Set 5 | caramay
# Processing Record 27 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 28 of Set 5 | longyearbyen
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | goderich
# Processing Record 32 of Set 5 | cabo san lucas
# Processing Record 33 of Set 5 | zonguldak
# Processing Record 34 of Set 5 | taoudenni
# Processing Record 35 of Set 5 | andilamena
# Processing Record 36 of Set 5 | lazaro cardenas
# Processing Record 37 of Set 5 | san patricio
# Processing Record 38 of Set 5 | kruisfontein
# Processing Record 39 of Set 5 | egvekinot
# Processing Record 40 of Set 5 | raga
# Processing Record 41 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 5 | tucuman
# Processing Record 43 of Set 5 | plonsk
# Processing Record 44 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 5 | krasnik
# Processing Record 46 of Set 5 | inirida
# Processing Record 47 of Set 5 | owando
# Processing Record 48 of Set 5 | saint-joseph
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 0 of Set 6 | portland
# Processing Record 1 of Set 6 | dois vizinhos
# Processing Record 2 of Set 6 | port moresby
# Processing Record 3 of Set 6 | cootamundra
# Processing Record 4 of Set 6 | baracoa
# Processing Record 5 of Set 6 | tigil
# Processing Record 6 of Set 6 | saldanha
# Processing Record 7 of Set 6 | nishihara
# Processing Record 8 of Set 6 | karauzyak
# City not found. Skipping...
# Processing Record 9 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 10 of Set 6 | colac
# Processing Record 11 of Set 6 | poronaysk
# Processing Record 12 of Set 6 | kropotkin
# Processing Record 13 of Set 6 | taunggyi
# Processing Record 14 of Set 6 | liwale
# Processing Record 15 of Set 6 | deputatskiy
# Processing Record 16 of Set 6 | chernyshevskiy
# Processing Record 17 of Set 6 | emerald
# Processing Record 18 of Set 6 | port-gentil
# Processing Record 19 of Set 6 | ponta do sol
# Processing Record 20 of Set 6 | rodrigues alves
# Processing Record 21 of Set 6 | dagshai
# Processing Record 22 of Set 6 | dunedin
# Processing Record 23 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 6 | sao filipe
# Processing Record 25 of Set 6 | victoria
# Processing Record 26 of Set 6 | yulara
# Processing Record 27 of Set 6 | pirovskoye
# Processing Record 28 of Set 6 | nuzvid
# Processing Record 29 of Set 6 | vallenar
# Processing Record 30 of Set 6 | lahaina
# Processing Record 31 of Set 6 | vestmannaeyjar
# Processing Record 32 of Set 6 | kijang
# Processing Record 33 of Set 6 | east london
# Processing Record 34 of Set 6 | balvi
# Processing Record 35 of Set 6 | guanica
# Processing Record 36 of Set 6 | aloleng
# Processing Record 37 of Set 6 | miranorte
# City not found. Skipping...
# Processing Record 38 of Set 6 | hithadhoo
# Processing Record 39 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 6 | cururupu
# Processing Record 41 of Set 6 | arlit
# Processing Record 42 of Set 6 | meulaboh
# Processing Record 43 of Set 6 | grand gaube
# Processing Record 44 of Set 6 | la asuncion
# Processing Record 45 of Set 6 | garm
# City not found. Skipping...
# Processing Record 46 of Set 6 | aljezur
# Processing Record 47 of Set 6 | altamira
# Processing Record 48 of Set 6 | ondjiva
# Processing Record 49 of Set 6 | tasiilaq
# Processing Record 0 of Set 7 | hami
# Processing Record 1 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 7 | fortuna
# Processing Record 3 of Set 7 | xingyi
# Processing Record 4 of Set 7 | khasan
# Processing Record 5 of Set 7 | sinnamary
# Processing Record 6 of Set 7 | aleksin
# Processing Record 7 of Set 7 | fowa
# Processing Record 8 of Set 7 | dauphin
# Processing Record 9 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 7 | felanitx
# Processing Record 12 of Set 7 | saint-pierre
# Processing Record 13 of Set 7 | boa vista
# Processing Record 14 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 7 | tirat karmel
# Processing Record 16 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 17 of Set 7 | constantine
# Processing Record 18 of Set 7 | ransang
# Processing Record 19 of Set 7 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 7 | gijon
# Processing Record 21 of Set 7 | bandarbeyla
# Processing Record 22 of Set 7 | cascais
# Processing Record 23 of Set 7 | rio grande
# Processing Record 24 of Set 7 | kuminskiy
# Processing Record 25 of Set 7 | takestan
# Processing Record 26 of Set 7 | atar
# Processing Record 27 of Set 7 | salalah
# Processing Record 28 of Set 7 | hovd
# Processing Record 29 of Set 7 | aktash
# Processing Record 30 of Set 7 | jalingo
# Processing Record 31 of Set 7 | lakes entrance
# Processing Record 32 of Set 7 | rio gallegos
# Processing Record 33 of Set 7 | puqi
# Processing Record 34 of Set 7 | vila
# Processing Record 35 of Set 7 | sao joao da barra
# Processing Record 36 of Set 7 | khonsa
# Processing Record 37 of Set 7 | srednekolymsk
# Processing Record 38 of Set 7 | kirkuk
# Processing Record 39 of Set 7 | qianan
# Processing Record 40 of Set 7 | baiyin
# Processing Record 41 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 42 of Set 7 | khandyga
# Processing Record 43 of Set 7 | los llanos de aridane
# Processing Record 44 of Set 7 | imperia
# Processing Record 45 of Set 7 | bajo baudo
# City not found. Skipping...
# Processing Record 46 of Set 7 | amalfi
# Processing Record 47 of Set 7 | lagoa
# Processing Record 48 of Set 7 | kirzhach
# Processing Record 49 of Set 7 | yeppoon
# Processing Record 0 of Set 8 | yumen
# Processing Record 1 of Set 8 | rundu
# Processing Record 2 of Set 8 | gilgit
# Processing Record 3 of Set 8 | khash
# Processing Record 4 of Set 8 | saint-augustin
# Processing Record 5 of Set 8 | gizo
# Processing Record 6 of Set 8 | codrington
# Processing Record 7 of Set 8 | beloha
# Processing Record 8 of Set 8 | nelson bay
# Processing Record 9 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 10 of Set 8 | kita
# Processing Record 11 of Set 8 | zhuozhou
# City not found. Skipping...
# Processing Record 12 of Set 8 | pandan
# Processing Record 13 of Set 8 | calabozo
# Processing Record 14 of Set 8 | xining
# Processing Record 15 of Set 8 | kasongo-lunda
# Processing Record 16 of Set 8 | buchanan
# Processing Record 17 of Set 8 | caravelas
# Processing Record 18 of Set 8 | play cu
# City not found. Skipping...
# Processing Record 19 of Set 8 | sobolevo
# Processing Record 20 of Set 8 | linhares
# Processing Record 21 of Set 8 | roald
# Processing Record 22 of Set 8 | barranca
# Processing Record 23 of Set 8 | yerbogachen
# Processing Record 24 of Set 8 | huarmey
# Processing Record 25 of Set 8 | eugene
# Processing Record 26 of Set 8 | selma
# Processing Record 27 of Set 8 | pundaguitan
# Processing Record 28 of Set 8 | senanga
# Processing Record 29 of Set 8 | ambilobe
# Processing Record 30 of Set 8 | dalvik
# Processing Record 31 of Set 8 | wanning
# Processing Record 32 of Set 8 | vardo
# Processing Record 33 of Set 8 | bani
# Processing Record 34 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 8 | ust-kuyga
# Processing Record 36 of Set 8 | ereymentau
# Processing Record 37 of Set 8 | katobu
# Processing Record 38 of Set 8 | cap-aux-meules
# Processing Record 39 of Set 8 | zavallya
# Processing Record 40 of Set 8 | flinders
# Processing Record 41 of Set 8 | matamoros
# Processing Record 42 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 43 of Set 8 | livingstonia
# Processing Record 44 of Set 8 | karratha
# Processing Record 45 of Set 8 | mata grande
# Processing Record 46 of Set 8 | conde
# Processing Record 47 of Set 8 | kununurra
# Processing Record 48 of Set 8 | el carmen
# Processing Record 49 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 0 of Set 9 | guerrero negro
# Processing Record 1 of Set 9 | assiniboia
# Processing Record 2 of Set 9 | channel-port aux basques
# Processing Record 3 of Set 9 | praia
# Processing Record 4 of Set 9 | tanete
# Processing Record 5 of Set 9 | porbandar
# Processing Record 6 of Set 9 | trabzon
# Processing Record 7 of Set 9 | haines junction
# Processing Record 8 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 9 of Set 9 | olafsvik
# Processing Record 10 of Set 9 | clyde river
# Processing Record 11 of Set 9 | antofagasta
# Processing Record 12 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 13 of Set 9 | owensboro
# Processing Record 14 of Set 9 | komsomolskiy
# Processing Record 15 of Set 9 | babstovo
# Processing Record 16 of Set 9 | subaytilah
# City not found. Skipping...
# Processing Record 17 of Set 9 | grand forks
# Processing Record 18 of Set 9 | zeya
# Processing Record 19 of Set 9 | concarneau
# Processing Record 20 of Set 9 | bathsheba
# Processing Record 21 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 22 of Set 9 | rawah
# Processing Record 23 of Set 9 | sokolo
# Processing Record 24 of Set 9 | carquefou
# Processing Record 25 of Set 9 | sadowara
# City not found. Skipping...
# Processing Record 26 of Set 9 | chivay
# Processing Record 27 of Set 9 | ust-maya
# Processing Record 28 of Set 9 | mirnyy
# Processing Record 29 of Set 9 | marzuq
# Processing Record 30 of Set 9 | puerto colombia
# Processing Record 31 of Set 9 | sergeyevka
# Processing Record 32 of Set 9 | salisbury
# Processing Record 33 of Set 9 | coihaique
# Processing Record 34 of Set 9 | sinjai
# Processing Record 35 of Set 9 | panguipulli
# Processing Record 36 of Set 9 | thunder bay
# Processing Record 37 of Set 9 | san juan
# Processing Record 38 of Set 9 | mecca
# Processing Record 39 of Set 9 | keokuk
# Processing Record 40 of Set 9 | cabatuan
# Processing Record 41 of Set 9 | harper
# Processing Record 42 of Set 9 | pevek
# Processing Record 43 of Set 9 | san jose
# Processing Record 44 of Set 9 | okhotsk
# Processing Record 45 of Set 9 | gravelbourg
# Processing Record 46 of Set 9 | tres arroyos
# Processing Record 47 of Set 9 | edd
# Processing Record 48 of Set 9 | maniitsoq
# Processing Record 49 of Set 9 | umm lajj
# Processing Record 0 of Set 10 | cassilandia
# Processing Record 1 of Set 10 | akhtanizovskaya
# Processing Record 2 of Set 10 | novyy svit
# Processing Record 3 of Set 10 | khartoum
# Processing Record 4 of Set 10 | ust-nera
# Processing Record 5 of Set 10 | kapit
# Processing Record 6 of Set 10 | changying
# Processing Record 7 of Set 10 | canon city
# Processing Record 8 of Set 10 | vanimo
# Processing Record 9 of Set 10 | murgab
# Processing Record 10 of Set 10 | kapoeta
# Processing Record 11 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 10 | byron bay
# Processing Record 13 of Set 10 | avera
# Processing Record 14 of Set 10 | ninotsminda
# Processing Record 15 of Set 10 | rossland
# Processing Record 16 of Set 10 | caucaia
# Processing Record 17 of Set 10 | tautira
# Processing Record 18 of Set 10 | camacha
# Processing Record 19 of Set 10 | churachandpur
# Processing Record 20 of Set 10 | pervomayskiy
# Processing Record 21 of Set 10 | hashtrud
# Processing Record 22 of Set 10 | fuglebjerg
# Processing Record 23 of Set 10 | anadyr
# Processing Record 24 of Set 10 | fort nelson
# Processing Record 25 of Set 10 | peskovka
# Processing Record 26 of Set 10 | saint anthony
# Processing Record 27 of Set 10 | cochabamba
# Processing Record 28 of Set 10 | celestun
# Processing Record 29 of Set 10 | noyabrsk
# Processing Record 30 of Set 10 | samarai
# Processing Record 31 of Set 10 | sawakin
# Processing Record 32 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 10 | khuzhir
# Processing Record 34 of Set 10 | porto murtinho
# Processing Record 35 of Set 10 | pawai
# Processing Record 36 of Set 10 | marquette
# Processing Record 37 of Set 10 | kruszwica
# Processing Record 38 of Set 10 | turukhansk
# Processing Record 39 of Set 10 | bac lieu
# Processing Record 40 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 10 | pitkyaranta
# Processing Record 42 of Set 10 | smithers
# Processing Record 43 of Set 10 | mana
# Processing Record 44 of Set 10 | matara
# Processing Record 45 of Set 10 | bahia de caraquez
# Processing Record 46 of Set 10 | mount isa
# Processing Record 47 of Set 10 | biltine
# Processing Record 48 of Set 10 | kampot
# Processing Record 49 of Set 10 | suoyarvi
# Processing Record 0 of Set 11 | hobbs
# Processing Record 1 of Set 11 | fujin
# Processing Record 2 of Set 11 | svetlaya
# Processing Record 3 of Set 11 | yelizovo
# Processing Record 4 of Set 11 | ulaanbaatar
# Processing Record 5 of Set 11 | bogatic
# Processing Record 6 of Set 11 | dhulian
# Processing Record 7 of Set 11 | sao marcos
# Processing Record 8 of Set 11 | hope
# Processing Record 9 of Set 11 | salinopolis
# Processing Record 10 of Set 11 | sibu
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | yantzaza
# Processing Record 13 of Set 11 | paita
# Processing Record 14 of Set 11 | shelburne
# Processing Record 15 of Set 11 | sambava
# Processing Record 16 of Set 11 | champerico
# Processing Record 17 of Set 11 | goma
# Processing Record 18 of Set 11 | tual
# Processing Record 19 of Set 11 | aykhal
# Processing Record 20 of Set 11 | lampang
# Processing Record 21 of Set 11 | siniscola
# Processing Record 22 of Set 11 | anaconda
# Processing Record 23 of Set 11 | waingapu
# Processing Record 24 of Set 11 | san angelo
# Processing Record 25 of Set 11 | keti bandar
# Processing Record 26 of Set 11 | kariba
# Processing Record 27 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 28 of Set 11 | toktogul
# Processing Record 29 of Set 11 | aranda de duero
# Processing Record 30 of Set 11 | mumbwa
# Processing Record 31 of Set 11 | rognan
# Processing Record 32 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 11 | sorland
# Processing Record 35 of Set 11 | vilcun
# Processing Record 36 of Set 11 | bubaque
# Processing Record 37 of Set 11 | vigrestad
# Processing Record 38 of Set 11 | saurimo
# Processing Record 39 of Set 11 | havre
# Processing Record 40 of Set 11 | lephepe
# City not found. Skipping...
# Processing Record 41 of Set 11 | isiro
# Processing Record 42 of Set 11 | half moon bay
# Processing Record 43 of Set 11 | severo-yeniseyskiy
# Processing Record 44 of Set 11 | eureka
# Processing Record 45 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 46 of Set 11 | tilichiki
# Processing Record 47 of Set 11 | lorengau
# Processing Record 48 of Set 11 | chitral
# Processing Record 49 of Set 11 | kieta
# Processing Record 0 of Set 12 | lulea
# Processing Record 1 of Set 12 | zyryanka
# Processing Record 2 of Set 12 | batticaloa
# Processing Record 3 of Set 12 | kattivakkam
# Processing Record 4 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 12 | kipushi
# Processing Record 6 of Set 12 | buala
# Processing Record 7 of Set 12 | pingliang
# Processing Record 8 of Set 12 | monywa
# Processing Record 9 of Set 12 | gamba
# Processing Record 10 of Set 12 | zaranj
# Processing Record 11 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 12 | nantucket
# Processing Record 13 of Set 12 | leh
# Processing Record 14 of Set 12 | aksu
# Processing Record 15 of Set 12 | yuli
# Processing Record 16 of Set 12 | yangjiang
# Processing Record 17 of Set 12 | coahuayana
# Processing Record 18 of Set 12 | ketchikan
# Processing Record 19 of Set 12 | the pas
# Processing Record 20 of Set 12 | nieuw amsterdam
# Processing Record 21 of Set 12 | ustrzyki dolne
# Processing Record 22 of Set 12 | tabas
# Processing Record 23 of Set 12 | manoel urbano
# Processing Record 24 of Set 12 | leningradskiy
# Processing Record 25 of Set 12 | bilibino
# Processing Record 26 of Set 12 | winsford
# Processing Record 27 of Set 12 | kyzyl-suu
# Processing Record 28 of Set 12 | manaus
# Processing Record 29 of Set 12 | rypefjord
# Processing Record 30 of Set 12 | awjilah
# Processing Record 31 of Set 12 | hay river
# Processing Record 32 of Set 12 | lumsden
# Processing Record 33 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 34 of Set 12 | bom jesus da lapa
# Processing Record 35 of Set 12 | rio cuarto
# Processing Record 36 of Set 12 | palmer
# Processing Record 37 of Set 12 | verkhnyaya inta
# Processing Record 38 of Set 12 | innisfail
# Processing Record 39 of Set 12 | creston
# Processing Record 40 of Set 12 | tukums
# Processing Record 41 of Set 12 | kadom
# Processing Record 42 of Set 12 | cuenca
# Processing Record 43 of Set 12 | mbandaka
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          538
# Lat           538
# Lng           538
# Max Temp      538
# Humidity      538
# Cloudiness    538
# Wind Speed    538
# Country       538
# Date          538
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  nambucca heads -30.6500  153.0000    291.15        66           5
# 1           nijar  36.9665   -2.2060    297.40        47           0
# 2       jamestown  42.0970  -79.2353    295.92        74           0
# 3          atuona  -9.8000 -139.0333    298.50        72          70
# 4         avallon  47.4833    3.9000    286.15        83          66
#
#    Wind Speed Country        Date
# 0        2.67      AU  1691277968
# 1        1.54      ES  1691277968
# 2        3.09      US  1691277792
# 3        4.44      PF  1691277969
# 4        7.81      FR  1691277969

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        nambucca heads -30.6500  153.0000    291.15        66           5
# 1                 nijar  36.9665   -2.2060    297.40        47           0
# 2             jamestown  42.0970  -79.2353    295.92        74           0
# 3                atuona  -9.8000 -139.0333    298.50        72          70
# 4               avallon  47.4833    3.9000    286.15        83          66
#
#          Wind Speed Country        Date
# City_ID
# 0              2.67      AU  1691277968
# 1              1.54      ES  1691277968
# 2              3.09      US  1691277792
# 3              4.44      PF  1691277969
# 4              7.81      FR  1691277969

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_axis = city_data_df['Lat']
y_axis = city_data_df['Max Temp']
plt.scatter(x_axis, y_axis, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.grid(visible=True)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs. Temperature (2023-8-5)')

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_axis = city_data_df['Lat']
y_axis = city_data_df['Humidity']
plt.scatter(x_axis, y_axis, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.grid(visible=True)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (2023-8-5)')

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_axis = city_data_df['Lat']
y_axis = city_data_df['Cloudiness']
plt.scatter(x_axis, y_axis, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.grid(visible=True)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (2023-8-5)')

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_axis = city_data_df['Lat']
y_axis = city_data_df['Wind Speed']
plt.scatter(x_axis, y_axis, marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.grid(visible=True)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed (2023-8-5)')

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linearRegression(x_values, y_values, regEQplotX, regEQplotY, y_label):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    print(f'The r-square is {rvalue}')
    print(line_eq)
    plt.annotate(line_eq,(regEQplotX,regEQplotY),fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(f'{y_label}')
    plt.grid()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1               nijar  36.9665   -2.2060    297.40        47           0
# 2           jamestown  42.0970  -79.2353    295.92        74           0
# 4             avallon  47.4833    3.9000    286.15        83          66
# 5                nome  64.5011 -165.4064    288.24        72         100
# 10       nefteyugansk  61.0998   72.6035    287.10        66           6
#
#          Wind Speed Country        Date
# City_ID
# 1              1.54      ES  1691277968
# 2              3.09      US  1691277792
# 4              7.81      FR  1691277969
# 5             11.83      US  1691277970
# 10             3.24      RU  1691277972

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        nambucca heads -30.6500  153.0000    291.15        66           5
# 3                atuona  -9.8000 -139.0333    298.50        72          70
# 6               ahipara -35.1667  173.1667    285.83        67          46
# 7                hobart -42.8794  147.3294    284.85        79          75
# 8               mataura -46.1927  168.8643    283.42        79         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.67      AU  1691277968
# 3              4.44      PF  1691277969
# 6              1.88      NZ  1691277971
# 7              4.63      AU  1691277971
# 8              1.39      NZ  1691277971

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
t_north_x = northern_hemi_df['Lat']
t_north_y = northern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(t_north_x, t_north_y)
regress_val = t_north_x * slope + intercept
lin_reg_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))

plt.scatter(t_north_x, t_north_y)
plt.plot(t_north_x,regress_val,"r-")
plt.annotate(lin_reg_eq,(5,-20),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Max Temp')


print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.4292718872170149

# %%
# Linear regression on Southern Hemisphere
t_south_x = southern_hemi_df['Lat']
t_south_y = southern_hemi_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr) = linregress(t_south_x, t_south_y)
s_regress_val = t_south_x * slope + intercept
s_lin_reg_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))

plt.scatter(t_south_x, t_south_y)
plt.plot(t_south_x,s_regress_val,"r-")
plt.annotate(s_lin_reg_eq,(-55,27),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Max Temp')


print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.6707532809676244

# %% [markdown]
# **Discussion about the linear relationship:** This data does seem to have a linear relationship and in each case has a close relation to the best fit line

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
h_north_x = northern_hemi_df['Lat']
h_north_y = northern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(h_north_x, h_north_y)
nh_regress_val = h_north_x * slope + intercept
nh_lin_reg_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))

plt.scatter(h_north_x, h_north_y)
plt.plot(h_north_x,nh_regress_val,"r-")
plt.annotate(nh_lin_reg_eq,(45,20),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Humidity')


print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.002008255887436041

# %%
# Southern Hemisphere
h_south_x = southern_hemi_df['Lat']
h_south_y = southern_hemi_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr) = linregress(h_south_x, h_south_y)
sh_regress_val = h_south_x * slope + intercept
sh_lin_reg_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))

plt.scatter(h_south_x, h_south_y)
plt.plot(h_south_x,sh_regress_val,"r-")
plt.annotate(sh_lin_reg_eq,(-55,40),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Humidity')


print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.008586063295912804

# %% [markdown]
# **Discussion about the linear relationship:** This does not seem to have any close linear relationship, seems that the data has no relationship with each other

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
c_north_x = northern_hemi_df['Lat']
c_north_y = northern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(c_north_x, c_north_y)
cn_regress_val = c_north_x * slope + intercept
cn_lin_reg_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))

plt.scatter(c_north_x, c_north_y)
plt.plot(c_north_x,cn_regress_val,"r-")
plt.annotate(cn_lin_reg_eq,(8,87),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')


print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0009709031830329567

# %%
# Southern Hemisphere
c_south_x = southern_hemi_df['Lat']
c_south_y = southern_hemi_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr) = linregress(c_south_x, c_south_y)
sc_regress_val = c_south_x * slope + intercept
sc_lin_reg_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))

plt.scatter(c_south_x, c_south_y)
plt.plot(c_south_x,sc_regress_val,"r-")
plt.annotate(sc_lin_reg_eq,(-55,20),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')


print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0027677175973069646

# %% [markdown]
# **Discussion about the linear relationship:** R-value on both of these are very low and has no linear relationship

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
w_northern_x = northern_hemi_df['Lat']
w_northern_y = northern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(w_northern_x, w_northern_y)
nw_regress_val = w_northern_x * slope + intercept
nw_lin_reg_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))

plt.scatter(w_northern_x, w_northern_y)
plt.plot(w_northern_x,nw_regress_val,"r-")
plt.annotate(nw_lin_reg_eq,(0,15),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')


print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 5.260091262892381e-05

# %%
# Southern Hemisphere
w_southern_x = southern_hemi_df['Lat']
w_southern_y = southern_hemi_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr) = linregress(w_southern_x, w_southern_y)
sw_regress_val = w_southern_x * slope + intercept
sw_lin_reg_eq = "Y = " + str(round(slope,2)) + "X + " + str(round(intercept,2))

plt.scatter(w_southern_x, w_southern_y)
plt.plot(w_southern_x,sw_regress_val,"r-")
plt.annotate(sw_lin_reg_eq,(-52,8.5),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')


print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.014040692296158367

# %% [markdown]
# **Discussion about the linear relationship:** Nost of the data is focused in one area but the linear relationship does represent a good amount of the data
